# %%
import pandas as pd
import numpy as np
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
from tensorflow.keras.models import load_model
# Out:
# WARNING:tensorflow:From d:\Projects\ANN-Classification\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# load the preprocessor
preprocessor_path="../../artifacts/classification/preprocessor.pkl"
with open(preprocessor_path,'rb') as file:
    preprocessor=pickle.load(file)

# %%
# load the model
model_path="../../artifacts/classification/model.h5"
model=load_model(model_path)
# Out:
# WARNING:tensorflow:From d:\Projects\ANN-Classification\venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
# Example input data
input_data = {
    'CreditScore': [ 600],
    'Geography': [ 'France'],
    'Gender': ['Male'],
    'Age': [40],
    'Tenure': [3],
    'Balance': [60000],
    'NumOfProducts': [2],
    'HasCrCard': [1],
    'IsActiveMember': [1],
    'EstimatedSalary': [50000]
}

# %%
df=pd.DataFrame(input_data)

# %%
df_transformed=preprocessor.transform(df)

# %%
pred_prob=model.predict(df_transformed)
# Out:
# 1/1 [==============================] - 0s 31ms/step

# %%
print(pred_prob)
# Out:
# [[0.06214841]]

# %%
if pred_prob > 0.5:
    print("Customer is likely to churn")
else:
    print("Customer is not likely to churn")
# Out:
# Customer is not likely to churn
